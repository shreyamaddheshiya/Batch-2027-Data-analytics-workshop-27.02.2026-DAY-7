# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Data%20Discretization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Marks': [35, 67, 89, 45, 72, 90, 55, 60]}
df = pd.DataFrame(data)
df['Equal_Width_Bins'] = pd.cut(df['Marks'], bins=3)
print(df)
# Out:
#    Marks  Equal_Width_Bins
# 0     35  (34.945, 53.333]
# 1     67  (53.333, 71.667]
# 2     89    (71.667, 90.0]
# 3     45  (34.945, 53.333]
# 4     72    (71.667, 90.0]
# 5     90    (71.667, 90.0]
# 6     55  (53.333, 71.667]
# 7     60  (53.333, 71.667]
