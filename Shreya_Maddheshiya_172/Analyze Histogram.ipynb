# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Analyze%20Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bins = [30, 45, 60, 75, 90, 100]
labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
df['Category'] = pd.cut(df['Marks'], bins=bins, labels=labels)
print(df)
# Out:
#     Marks  Category
# 0      35  Very Low
# 1      45  Very Low
# 2      50       Low
# 3      55       Low
# 4      60       Low
# 5      65    Medium
# 6      70    Medium
# 7      75    Medium
# 8      80      High
# 9      85      High
# 10     90      High
